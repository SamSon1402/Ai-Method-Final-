# %%
# !pip install mlflow
import mlflow

# Set the experiment name
mlflow.set_experiment("E-Commerce Customer Churn Prediction")

# Optional: Specify the tracking URI if you want to log runs remotely
# mlflow.set_tracking_uri('your_tracking_uri')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
# ...

# %%
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Load the dataset
df = pd.read_excel('/content/E Commerce Dataset.xlsx', sheet_name='E Comm')

# Assuming 'Churn' is the target and 'CustomerID' is not a feature
X = df.drop(['Churn', 'CustomerID'], axis=1)
y = df['Churn']

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the preprocessing for the 'DeviceType' column
# Adjust according to the actual categorical columns needing encoding in your dataset
column_trans = ColumnTransformer(
    [('ohe', OneHotEncoder(), ['phone'])],  # Replace 'YourActualColumnNameHere' with the correct column name
    remainder='passthrough'
)

# Define the modeling pipeline
pipeline = Pipeline([
    ('preprocessing', column_trans),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42))
])

# Set MLflow experiment
mlflow.set_experiment("E-Commerce Customer Churn Prediction")

with mlflow.start_run(run_name="Model_with_Preprocessing"):
    # Log model parameters (if any)
    mlflow.log_param("n_estimators", 100)
    mlflow.log_param("max_depth", 5)
    mlflow.log_param("random_state", 42)

    # Fit the model
    pipeline.fit(X_train, y_train)

    # Make predictions
    y_pred = pipeline.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("accuracy", accuracy)
    print(f"Accuracy: {accuracy}")
    print(confusion_matrix(y_test, y_pred))

    # Log the pipeline
    mlflow.sklearn.log_model(pipeline, "model")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'phone'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import shutil

# Source folder you want to zip
source_folder = '/content'

# Destination zip file path
destination_zip = '/content/your_zip_file_name.zip'

# Create a zip file from the source folder
shutil.make_archive(destination_zip, 'zip', source_folder)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1775             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1776                 shutil.copyfileobj(src, dest, 1024*8)
#    1777
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     197             break
# --> 198         fdst_write(buf)
#     199
#
# /usr/lib/python3.10/zipfile.py in write(self, data)
#    1138         if self._compressor:
# -> 1139             data = self._compressor.compress(data)
#    1140             self._compress_size += len(data)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-e6a2629849de> in <cell line: 10>()
# ...

# %%
# Zip the contents of a folder
# !zip -r /content/your_zip_file_name.zip /content/mlruns
# Out:
#   adding: content/mlruns/ (stored 0%)
#   adding: content/mlruns/.trash/ (stored 0%)
#   adding: content/mlruns/115997481459651455/ (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/ (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/tags/ (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/tags/mlflow.source.name (deflated 5%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/tags/mlflow.user (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/tags/mlflow.runName (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/tags/mlflow.source.type (stored 0%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/meta.yaml (deflated 45%)
#   adding: content/mlruns/115997481459651455/debbaa09f146448989ec22672cdc4a43/metrics/ (stored 0%)
# ...
